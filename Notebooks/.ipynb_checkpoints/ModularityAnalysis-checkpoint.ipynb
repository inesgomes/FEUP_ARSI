# %% [markdown]
# In this notebook I'll make a **Modularity analysis**, in order to see clusters.
#
# First, I runned the 'Modularity Statistic' on Gephi and exported the results.
#
# Then, I opened the CSV and divided the videos per Modularity Class.
#
# Finally I could take two conclusions:
#     1. categories associated to certain modularities
#     2. channels associated to certain modularities
#     3. tags associated to certatin modularities
#
# *Attention* : the dataset analysed was GB+US with weightned edges.

# %%
import pandas as pd

nodesOriginal = pd.read_csv('../CreatedCSVs/GephiNodesGBUS.csv', sep=',', decimal='.', header=0)
nodesOriginal.head()
# Out:
#             Id                                              Label  timeset  \
# 0  AumaWl0TNBo                       How My Relationship Started!      NaN
# 1  -N5eucPMTTc                      CHRISTMAS HAS GONE TO MY HEAD      NaN
# 2  fiusxyygqGk       Marshmello - You & Me (Official Music Video)      NaN
# 3  sLJdBmAeB_U  COME SHOPPING WITH ME AND TRY ON NEW CLOTHING ...      NaN
# 4  mCx26FLXWuI  Seth Rollins & Dean Ambrose vs. Cesaro & Sheam...      NaN
#
#         channel_title  category_id        trending_date         publish_time  \
# 0  PointlessBlogVlogs           24  2017-11-14 00:00:00  2017-11-11 17:00:00
# 1          MoreZoella           22  2017-11-14 00:00:00  2017-11-10 19:19:43
# 2          marshmello           10  2017-11-14 00:00:00  2017-11-10 15:00:03
# 3           Inthefrow           26  2017-11-14 00:00:00  2017-11-07 19:00:50
# 4                 WWE           17  2017-11-14 00:00:00  2017-11-07 04:52:25
#
#      views   likes  dislikes  comment_count  modularity_class
# 0  1182775   52708      1431           2333                 0
# 1  1164201   57309       749            624                 0
# 2  3407008  207262      3167          13279                 4
# 3    87772    2617        86            192                 0
# 4  1689382   24186      3330           3414                 1

# %% [markdown]
# In this case, I've 15 modularities.
#
# Example of dataframe with modularity = 1

# %%
nodes1 = nodesOriginal.loc[:, ['Id','channel_title','category_id','modularity_class']]

subNodes = []

for i in range(0, 15):
    subNodes.append(nodes1[nodes1.modularity_class == i])

subNodes[1].head()
# Out:
#              Id      channel_title  category_id  modularity_class
# 4   mCx26FLXWuI                WWE           17                 1
# 11  1eS_17CG9sk        Hazel Hayes           22                 1
# 25  8gFGhT5GpAs                WWE           17                 1
# 40  jgshHi6XjJ0                WWE           17                 1
# 47  b-ufhlIlfmA  Stephen Howson FC           17                 1

# %% [markdown]
# ### First Conclusion
#
# Which categories are associated to each cluster?

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

subplots = [131,132,133]
for j in range(0,5):
    plt.figure(1, figsize=(9, 3))
    c1 = j*3
    for i in range(0,3):
        #count number of categories for each subdataframe
        no = subNodes[c1+i]['category_id'].value_counts()
        plt.subplot(subplots[i])
        names = no.index.tolist()
        values = no.values.tolist()
        plt.bar(names, values)
        plt.xlabel("category id's")
    c2 = c1+2;
    plt.suptitle("Modularity classes from "+ str(c1) + " to "+ str(c2) )
    plt.show()

# %% [markdown]
# ### Second Conclusion
#
# Which channels are associated to each cluster?

# %%
subplots = [131,132,133]
for j in range(0,5):
    plt.figure(1, figsize=(9, 3))
    c1 = j*3
    for i in range(0,3):
        #count number of categories for each subdataframe
        no = subNodes[c1+i]['channel_title'].value_counts()
        plt.subplot(subplots[i])
        names = no.index.tolist()
        values = no.values.tolist()
        plt.bar(names, values)
        plt.xlabel("channels")
        frame1 = plt.gca()
        frame1.axes.xaxis.set_ticklabels([])
    c2 = c1+2;
    plt.suptitle("Modularity classes from "+ str(c1) + " to "+ str(c2) )
    plt.show()

# %% [markdown]
# ### Third Conclusion
#
# Which tags are associated to each cluster?
#
# This conclusion cannot be made with a dataset as big as GB + US.
# So, I'll just use th 6 smallest communities.

# %%
def strToList(tags):
    l = len(tags)
    return tags[2:l-2].split('\', \'')

def createPairsGetTags(nodes):
    tags = []
    for i, video1 in nodes.iterrows():
        for j, video2 in nodes.iterrows():
            if j > i:
                #verify if this pair has tags
                video = edges[(edges['Source'] == video1.Id) & (edges['Target'] == video2.Id)]
                if video.empty:
                    video = edges[(edges['Source'] == video2.Id) & (edges['Target'] == video1.Id)]
                if video.empty == False:
                    list_tags = strToList(video.Tags.values[0])
                    tags = tags + list_tags
    return tags

def printResults(tags, c):
    counter = collections.Counter(tags)
    names = []
    values =[]
    for key, value in counter.items():
        names.append(key)
        values.append(value)
    plt.bar(names, values)
    plt.xlabel("tags")
    frame1 = plt.gca()
    frame1.axes.xaxis.set_ticklabels([])
    print("Community "+ str(c) +" Tag Names : ")
    print(names)

subplots = [131,132,133]
#smallest ones
communities = [5,8,10,11,12,14]

for i in range(0,2):
    plt.figure(1, figsize=(9, 3))
    c1 = i*3
    for j in range(0,3):
        videos = subNodes[communities[c1+j]]
        #fazer todos os pares possiveis de videos dentro do dataframe
        tags = createPairsGetTags(videos)
        #contagem de tags e print dos resultados
        plt.subplot(subplots[j])
        printResults(tags, communities[c1+j])
    plt.suptitle("Modularity classes "+str(communities[c1])+" , "+str(communities[c1+1])+" and "+ str(communities[c1+2]))
    plt.show()
# Out:
# Community 5 Tag Names :
# ['the scran line', 'how to make vanilla cupcakes', 'chocolate cupcakes', 'vanilla cupcakes', 'french macarons', 'pastry design', 'how to make macarons', 'nick makrides', 'easy cupcake recipes', 'how to pipe cupcakes', 'the scranline', 'over the top recipes', 'cupcakes']
# Community 8 Tag Names :
# ['doug demuro', 'demuro']
# Community 10 Tag Names :
# ['tv program', 'double jeopardy!', 'play jeopardy', 'reality games', 'Official Jeopardy!', 'Merv Griffin', 'exclusive jeopardy', 'think music', 'Game Show (TV Genre)', 'Jeopardy! (TV Program)', 'Jeopardy! best moments', 'Alex Trebek (TV Personality)', 'jeopardy!', 'Jeopardy questions\', "let\'s play']
# Community 11 Tag Names :
# ['three blue one brown', '3 blue 1 brown', '3b1b', 'Mathematics']
# Community 12 Tag Names :
# ['강승윤', '위너', '김진우', '이승훈', 'WINNER', '송민호']
# Community 14 Tag Names :
# ['videogamedunkey', 'dunkey']

# %%
#a little bit larger community
videos = subNodes[2]
#fazer todos os pares possiveis de videos dentro do dataframe
tags = createPairsGetTags(videos)
#contagem de tags e print dos resultados
printResults(tags, 2)
plt.suptitle("Modularity classe "+str(2))
plt.show()
